# %%
import pandas as pd

# %%
dataset=pd.read_csv("balanced_dataset.csv")

# %%
dataset
# Out:
#      app_name  response_time  error_rate  cpu_usage  memory_usage  disk_space  \
# 0         NIP             21          77         31            41          51
# 1         NIP             21           1         31            41          51
# 2         NIP             18          65         28            38          48
# 3         NIP             17          85         27            37          47
# 4         NIP             14          18         24            34          44
# ...       ...            ...         ...        ...           ...         ...
# 1163      NIP             10          54         20            30          40
# 1164      NIP             14          31         24            34          44
# 1165      NIP             18          95         28            38          48
# 1166      NIP             22          75         32            42          52
# 1167      NIP             18          30         28            38          48
#
#       active_users  downtime
# 0            11000         0
# 1            11000         0
# 2             8000         0
# 3             7000         0
# 4             4000         0
# ...            ...       ...
# 1163             0         1
# 1164          4000         1
# 1165          8000         1
# 1166         12000         1
# 1167          8000         1
#
# [1168 rows x 8 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       response_time  error_rate  cpu_usage  memory_usage  disk_space  \
# 0                21          77         31            41          51
# 1                21           1         31            41          51
# 2                18          65         28            38          48
# 3                17          85         27            37          47
# 4                14          18         24            34          44
# ...             ...         ...        ...           ...         ...
# 1163             10          54         20            30          40
# 1164             14          31         24            34          44
# 1165             18          95         28            38          48
# 1166             22          75         32            42          52
# 1167             18          30         28            38          48
#
#       active_users  downtime
# 0            11000         0
# 1            11000         0
# 2             8000         0
# 3             7000         0
# 4             4000         0
# ...            ...       ...
# 1163             0         1
# 1164          4000         1
# 1165          8000         1
# 1166         12000         1
# 1167          8000         1
#
# [1168 rows x 7 columns]

# %%
dataset.columns
# Out:
# Index(['response_time', 'error_rate', 'cpu_usage', 'memory_usage',
#        'disk_space', 'active_users', 'downtime'],
#       dtype='object')

# %%
indep=dataset[['response_time', 'error_rate', 'cpu_usage', 'memory_usage','disk_space', 'active_users']]

# %%
dep=dataset[['downtime']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split( indep, dep, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(x_train)
X_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'metric':['minkowski','callable'],
              'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
              'weights':['uniform','distance']}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'chebyshev', 'manhattan', 'braycurtis', 'pyfunc', 'sqeuclidean', 'canberra', 'dice', 'sokalsneath', 'infinity', 'haversine', 'nan_euclidean', 'cityblock', 'l1', 'hamming', 'seuclidean', 'euclidean', 'mahalanobis', 'cosine', 'russellrao', 'correlation', 'l2', 'sokalmichener', 'yule', 'precomputed', 'jaccard', 'p', 'minkowski', 'rogerstanimoto'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'cityblock', 'infinity', 'minkowski', 'nan_euclidean', 'mahalanobis', 'sqeuclidean', 'correlation', 'haversine', 'braycurtis', 'rogerstanimoto', 'jaccard', 'seuclidean', 'yule', 'precomputed', 'sokalmichener', 'l1', 'manhattan', 'hamming', 'chebyshev', 'russellrao', 'euclidean', 'canberra', 'sokalsneath', 'cosine', 'dice', 'pyfunc', 'p', 'l2'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'seuclidean', 'infinity', 'hamming', 'rogerstanimoto', 'correlation', 'nan_euclidean', 'sqeuclidean', 'cityblock', 'cosine', 'haversine', 'canberra', 'chebyshev', 'braycurtis', 'precomputed', 'yule', 'l1', 'sokalsneath', 'dice', 'euclidean', 'sokalmichener', 'jaccard', 'pyfunc', 'manhattan', 'p', 'russellrao', 'minkowski', 'l2', 'mahalanobis'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'canberra', 'pyfunc', 'euclidean', 'minkowski', 'rogerstanimoto', 'yule', 'manhattan', 'dice', 'sokalmichener', 'correlation', 'mahalanobis', 'haversine', 'chebyshev', 'russellrao', 'cosine', 'nan_euclidean', 'precomputed', 'l1', 'jaccard', 'braycurtis', 'l2', 'infinity', 'seuclidean', 'hamming', 'p', 'cityblock', 'sqeuclidean', 'sokalsneath'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'cosine', 'canberra', 'l2', 'manhattan', 'infinity', 'correlation', 'sqeuclidean', 'jaccard', 'yule', 'russellrao', 'l1', 'nan_euclidean', 'rogerstanimoto', 'cityblock', 'hamming', 'sokalmichener', 'minkowski', 'haversine', 'mahalanobis', 'pyfunc', 'sokalsneath', 'precomputed', 'braycurtis', 'dice', 'seuclidean', 'p', 'chebyshev', 'euclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'nan_euclidean', 'chebyshev', 'l1', 'rogerstanimoto', 'manhattan', 'mahalanobis', 'euclidean', 'haversine', 'l2', 'minkowski', 'dice', 'infinity', 'sokalmichener', 'hamming', 'cityblock', 'jaccard', 'precomputed', 'yule', 'cosine', 'correlation', 'sqeuclidean', 'seuclidean', 'canberra', 'sokalsneath', 'russellrao', 'pyfunc', 'p', 'braycurtis'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'canberra', 'mahalanobis', 'braycurtis', 'sokalmichener', 'cosine', 'correlation', 'manhattan', 'sqeuclidean', 'chebyshev', 'seuclidean', 'nan_euclidean', 'l1', 'euclidean', 'sokalsneath', 'precomputed', 'minkowski', 'infinity', 'rogerstanimoto', 'jaccard', 'p', 'russellrao', 'hamming', 'cityblock', 'haversine', 'pyfunc', 'yule', 'dice', 'l2'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'precomputed', 'nan_euclidean', 'l2', 'cosine', 'cityblock', 'yule', 'euclidean', 'sqeuclidean', 'sokalsneath', 'minkowski', 'mahalanobis', 'l1', 'chebyshev', 'hamming', 'infinity', 'seuclidean', 'sokalmichener', 'haversine', 'dice', 'manhattan', 'pyfunc', 'russellrao', 'canberra', 'rogerstanimoto', 'p', 'braycurtis', 'jaccard', 'correlation'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'precomputed', 'correlation', 'braycurtis', 'sqeuclidean', 'hamming', 'euclidean', 'seuclidean', 'pyfunc', 'canberra', 'cosine', 'russellrao', 'l1', 'infinity', 'sokalsneath', 'yule', 'nan_euclidean', 'chebyshev', 'manhattan', 'haversine', 'cityblock', 'minkowski', 'mahalanobis', 'dice', 'rogerstanimoto', 'sokalmichener', 'p', 'jaccard', 'l2'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'p', 'manhattan', 'dice', 'cosine', 'jaccard', 'canberra', 'chebyshev', 'minkowski', 'euclidean', 'russellrao', 'sokalmichener', 'braycurtis', 'rogerstanimoto', 'correlation', 'sokalsneath', 'l1', 'l2', 'yule', 'mahalanobis', 'cityblock', 'infinity', 'seuclidean', 'nan_euclidean', 'precomputed', 'hamming', 'haversine', 'pyfunc', 'sqeuclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'haversine', 'russellrao', 'yule', 'sokalmichener', 'canberra', 'infinity', 'p', 'seuclidean', 'chebyshev', 'correlation', 'mahalanobis', 'manhattan', 'l2', 'hamming', 'nan_euclidean', 'sokalsneath', 'jaccard', 'precomputed', 'pyfunc', 'l1', 'minkowski', 'dice', 'cityblock', 'cosine', 'sqeuclidean', 'braycurtis', 'euclidean', 'rogerstanimoto'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'dice', 'russellrao', 'mahalanobis', 'canberra', 'braycurtis', 'sokalsneath', 'jaccard', 'rogerstanimoto', 'pyfunc', 'seuclidean', 'infinity', 'correlation', 'yule', 'nan_euclidean', 'l2', 'chebyshev', 'minkowski', 'euclidean', 'manhattan', 'cityblock', 'l1', 'hamming', 'cosine', 'p', 'sqeuclidean', 'sokalmichener', 'precomputed', 'haversine'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'canberra', 'correlation', 'yule', 'hamming', 'sokalsneath', 'nan_euclidean', 'braycurtis', 'cosine', 'haversine', 'minkowski', 'jaccard', 'dice', 'sqeuclidean', 'manhattan', 'p', 'cityblock', 'infinity', 'sokalmichener', 'precomputed', 'chebyshev', 'euclidean', 'mahalanobis', 'pyfunc', 'l1', 'seuclidean', 'rogerstanimoto', 'l2', 'russellrao'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'precomputed', 'l2', 'euclidean', 'rogerstanimoto', 'manhattan', 'sokalmichener', 'correlation', 'yule', 'p', 'dice', 'sokalsneath', 'russellrao', 'infinity', 'canberra', 'l1', 'haversine', 'mahalanobis', 'braycurtis', 'pyfunc', 'cosine', 'chebyshev', 'nan_euclidean', 'sqeuclidean', 'cityblock', 'jaccard', 'seuclidean', 'hamming', 'minkowski'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'mahalanobis', 'minkowski', 'l1', 'chebyshev', 'canberra', 'braycurtis', 'seuclidean', 'rogerstanimoto', 'euclidean', 'cityblock', 'infinity', 'p', 'hamming', 'russellrao', 'sokalmichener', 'dice', 'nan_euclidean', 'l2', 'precomputed', 'haversine', 'yule', 'jaccard', 'sokalsneath', 'cosine', 'sqeuclidean', 'correlation', 'manhattan', 'pyfunc'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'infinity', 'seuclidean', 'p', 'euclidean', 'chebyshev', 'sokalsneath', 'l1', 'cosine', 'nan_euclidean', 'cityblock', 'haversine', 'sqeuclidean', 'russellrao', 'jaccard', 'manhattan', 'pyfunc', 'minkowski', 'hamming', 'dice', 'braycurtis', 'l2', 'mahalanobis', 'sokalmichener', 'yule', 'rogerstanimoto', 'precomputed', 'canberra', 'correlation'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'callable' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.87520624 0.8552992         nan        nan 0.87399473 0.8552992
#         nan        nan 0.87520624 0.8552992         nan        nan
#  0.87397533 0.85300156        nan        nan]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['minkowski', 'callable'],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("the f1_macro value for best parameter{}:".format(grid.best_params_),f1_macro)
# Out:
# the f1_macro value for best parameter{'algorithm': 'auto', 'metric': 'minkowski', 'weights': 'uniform'}: 0.8376083470123205

# %%
print("the confusion matrix:\n",cm)
# Out:
# the confusion matrix:
#  [[123  50]
#  [  6 172]]

# %%
print("the report:\n",clf_report)
# Out:
# the report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81       173
#            1       0.77      0.97      0.86       178
#
#     accuracy                           0.84       351
#    macro avg       0.86      0.84      0.84       351
# weighted avg       0.86      0.84      0.84       351
